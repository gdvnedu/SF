# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(start=-3., stop=3., num=1000)
y1 = np.exp(x)

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x, y1)

# %%
y2 = 10 + 0.4*x - 0.3*x**2 + 0.1*x**3

fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x[500:], y1[500:]) 
axes.plot(x, y2)

# %%
fig = plt.figure(figsize=(7, 4))
axes = fig.add_axes([0,0,1,1])
axes.plot(x, y1, linestyle= '-.')

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x[::30], y2[::30], 'mo')

# %%
x = np.linspace(start=-3., stop=3., num=1000)
y1 = np.exp(x)

fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x[300::10], y1[:700:10])
